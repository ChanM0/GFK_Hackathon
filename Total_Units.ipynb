# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
from decimal import Decimal


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 1000)

country_options = ['Germany','Great,Britain']
channel_options = ['Consumer,Electronic,Stores','Mass,Merchandisers/DIYSs']
year_options = [2016,2017,2018]
smart_connect_options = ['SMART,APP,CTRL.','VOICE,INTERAC.','VOICE,CONT.ONLY','n.a.','NO',Decimal('nan')]
smart_h_ecosys_options = ['n.a.','NOT,APPLICABLE','GOOG+AMZN','AMAZON,ALEXA','GOOGLE,HOME','APPLE,HOMEKIT',Decimal('nan')]
operating_ai_options = ['n.a.','NOT,APPLICABLE','GOOGLE,ASSISTAN','APPLE,SIRI','AMAZON,ALEXA',Decimal('nan')]
airplay_options = ['NO,AIRPLAY','AIRPLAY',Decimal('nan')]
googlecast_home_options = ['n.a.','NO,GOOGLECAST','GOOGLECAST/HOME',Decimal('nan')]
bluetooth_options = ['WITH,BLUETOOTH','W/O,BLUETOOTH','OPTIONAL',Decimal('nan')]
ethernet_options = ['NO,ETHERNET','ETHERNET',Decimal('nan')]
wifi_options = ['WIFI,BUILT-IN','NO,WIFI','WIFI,READY',Decimal('nan')]
high_res_audio_options = ['NO,HIGH-RES,AUD','HIGH-RES,AUDIO','n.a.',Decimal('nan')]
type_of_docking_options = ['BLUETOOTH,ONLY','NO,DOCKING/STRE','IOS/AIRPLAY','OTH.DOCK/STREAM','ANDR/GOOGLE,HOM','MULTIPLE']
multiroom_options = ['MULTIROOM','NO,MULTIROOM',Decimal('nan')]
no_speakerboxes_options = ['1','n.a.','0','2']
output_channel_options = [2,0]
streaming_connection_options = ['Bluetooth+Wifi','Bluetooth+Ethernet+Wifi','Wifi+Ethernet','Wifi','Ethernet','Bluetooth+Ethernet',Decimal('nan')]
streaming_technology_options = ['BT+UPNP','Proprietary,+BT','Bluetooth','n.a.','UPNP','BT+Airplay+UPNP',
                                'Proprietary,+BT,+Airplay,+UPNP','Airplay+UPNP','BT+Airplay,+UPNP,+Google,Cast/Home',
                                'Proprietary','Airplay','BT+UPNP,+Google,Cast/Home','BT+Google,Cast/Home','Bluetooth+Airplay',
                                'BT+Airplay,+Google,Cast/Home','Proprietary,+BT,+Airplay','Proprietary+Airplay',Decimal('nan')]
usb_connection_options = ['NO,USB','USB,TYPE-A/B',Decimal('nan')]
wattage_total_options = ['unknown','40','70','30','110','80','n.a.','150','90','60','45','300','5'
                         ,'240','140','154','50','20','29','75','14','55','92','38','15','320','25'
                         ,'10','72','13','100','130','200','120','18','65','250','180','175','36'
                         ,'17','450',Decimal('nan'),'35']

data = pd.DataFrame()

pivot_data_table = pd.DataFrame()
data_stats_table = pd.DataFrame()

address = './CSV_FILES/By_Country_POS_Tracking/GreatBritain.csv'

Germany_DF = pd.read_csv(address)
total_units = Germany_DF[['ID','MODEL', 'Sales Units']] # new DF with desired values
total_units = total_units.sort_values(by=['ID']) # sort DF by ID
total_units = total_units.reset_index(drop=True) # re-index
total_units['Sales Units'] = pd.to_numeric(total_units['Sales Units'], errors='coerce')
# print(total_units.head(3))

# begin running sum for each id algorithm
i = 0
r_sum = 0
stored_id = total_units['ID'].loc[i]
r_sum_DF = pd.DataFrame(columns=['MODEL','total_units_sold'])
# print(r_sum_DF)

for i in range(len(total_units)):
    if stored_id == total_units['ID'].loc[i]:
        r_sum = r_sum + total_units['Sales Units'].loc[i]
    else:
        # temp_DF = pd.DataFrame([[total_units['MODEL'].loc[i-1], r_sum]], columns=['MODEL','total_units_sold'])
        r_sum_DF.loc[len(r_sum_DF)] = [total_units['MODEL'].loc[i-1], r_sum]
        r_sum = total_units['Sales Units'].loc[i]
        stored_id = total_units['ID'].loc[i]

r_sum_DF = r_sum_DF.sort_values(by=['total_units_sold'],ascending=False)
r_sum_DF = r_sum_DF.reset_index(drop=True)
r_sum_DF.to_csv('./CSV_FILES/By_Country_POS_Tracking/GreatBritain_Units_Sold_by_ID.csv',index = None, header = True)

# %%
gbSortedIdsAdress = './CSV_FILES/By_Country_POS_Tracking/GreatBritain_Units_Sold_by_ID.csv'

GB_DF = pd.read_csv(gbSortedIdsAdress)

# %%
GB_DF
# Out:
#                                 MODEL  total_units_sold
# 0                               BOOST           13147.0
# 1      WAM 3500/WAM 3501 / SPEAKER R3            8311.0
# 2                              RHYTHM            7250.0
# 3                             LF-S50G            6958.0
# 4                            MU-SO QB            6145.0
# 5                               MU-SO            4609.0
# 6                             SRS-ZR5            4347.0
# 7                             SC-ALL2            4225.0
# 8                              WX-010            3836.0
# 9                            SC-ALL05            3699.0
# 10                             WX-030            2996.0
# 11                         HEOS 1 HS2            2785.0
# 12   SOUNDTOUCH WIRELESS LINK ADAPTER            2693.0
# 13                            SC-ALL6            1976.0
# 14             PLAY:5 (ZONEPLAYER S5)            1904.0
# 15                            SRS-ZR7            1753.0
# 16                             WXA-50            1676.0
# 17              WAM 5500 / SPEAKER R5            1608.0
# 18                               SA-5            1241.0
# 19                       HEOS AMP HS2            1148.0
# 20                            WXAD-10            1143.0
# 21                         BEOPLAY M5             964.0
# 22                             HEOS 1             950.0
# 23                         Suppressed             934.0
# 24                             WXC-50             924.0
# 25                         Suppressed             898.0
# 26                            SRS-X88             859.0
# 27                         UNITI ATOM             821.0
# 28                                BM5             785.0
# 29                         Suppressed             760.0
# 30                            VC-GX30             759.0
# 31                             HEOS 7             714.0
# 32                   HOME SPEAKER 500             699.0
# 33                            SC-GA10             660.0
# 34                         HEOS 3 HS2             641.0
# 35                                 S1             588.0
# 36                      HEOS LINK HS2             577.0
# 37               MUSIC FLOW H3 NP8340             546.0
# 38                             HEOS 5             529.0
# 39                         Suppressed             509.0
# 40                         Suppressed             499.0
# 41                         BEOPLAY A6             448.0
# 42                            SC-ALL9             433.0
# 43                         Suppressed             432.0
# 44                         Suppressed             413.0
# 45                            VC-PX30             409.0
# 46                           HOME MAX             387.0
# 47                         UNITI STAR             374.0
# 48                         Suppressed             335.0
# 49                         BEOPLAY M3             329.0
# 50                         Suppressed             320.0
# 51                  WAM 250 SMART HUB             316.0
# 52                         UNITI NOVA             291.0
# 53                    SMART DISPLAY 8             275.0
# 54        SOUNDTOUCH WIRELESS ADAPTER             270.0
# 55                     2 X HEOS 1 HS2             259.0
# 56                            SRS-X99             233.0
# 57                         Suppressed             232.0
# 58                WX-021 MUSICCAST 20             230.0
# 59                            SC-ALL8             230.0
# 60       WAM 550/WAM 551 / SPEAKER M5             223.0
# 61                      SOUNDTOUCH 30             208.0
# 62                         HEOS 7 HS2             205.0
# 63                   BR100 ZONEBRIDGE             187.0
# 64                            SC-ALL3             158.0
# 65                           SH-ALL1C             153.0
# 66               MUSIC FLOW H7 NP8740             150.0
# 67                         HEOS 5 HS2             150.0
# 68                             HEOS 3             142.0
# 69                            NX-N500             122.0
# 70                      SOUNDTOUCH 20             109.0
# 71                   SMART DISPLAY 10             108.0
# 72                         Suppressed             104.0
# 73                           HEOS AMP              92.0
# 74                         ARIES MINI              90.0
# 75               MUSIC FLOW H5 NP8540              86.0
# 76                         Suppressed              86.0
# 77                     RESTIO ISX-18D              80.0
# 78                         Suppressed              79.0
# 79                 NDX NETWORK PLAYER              77.0
# 80              ND5 XS NETWORK PLAYER              71.0
# 81                          2 PLAY:1S              66.0
# 82                         BEOSOUND 5              62.0
# 83       WAM 750/WAM 751 / SPEAKER M7              58.0
# 84                         Suppressed              57.0
# 85                         OMNI ADAPT              52.0
# 86                             ASSIST              45.0
# 87                            STAMMEN              41.0
# 88                             WX-051              37.0
# 89                         Suppressed              32.0
# 90                         Suppressed              27.0
# 91                         Suppressed              25.0
# 92                         Suppressed              24.0
# 93                         Suppressed              23.0
# 94                         Suppressed              22.0
# 95                  WOBURN MULTI-ROOM              20.0
# 96       WAM 350/WAM 351 / SPEAKER M3              18.0
# 97                          HEOS LINK              17.0
# 98                DUO (ISX-80+WX-030)              15.0
# 99                              ARENA              15.0
# 100                             MRX-3              14.0
# 101                       HEOS EXTEND              13.0
# 102            SOUNDTOUCH 30 SERIE II              11.0
# 103                           WAM 270              11.0
# 104                           OMNI 20               9.0
# 105                        Suppressed               8.0
# 106                   BEOSOUND 2 WIFI               8.0
# 107            SOUNDTOUCH PORTABLE II               8.0
# 108                           OMNI 10               8.0
# 109                        UNITI CORE               7.0
# 110                  ACTON MULTI-ROOM               7.0
# 111               SOUNDTOUCH PORTABLE               6.0
# 112                        Suppressed               5.0
# 113                        Suppressed               5.0
# 114                        Suppressed               4.0
# 115                  STRIIMLIGHT WIFI               4.0
# 116           DUETT (YSP-1600+WX-030)               3.0
# 117                        Suppressed               2.0
# 118                        Suppressed               1.0
# 119    WAM 7500/WAM 7501 / SPEAKER R7               NaN
# 120          SOUNDTOUCH 30 SERIES III               NaN
# 121                     SOUNDTOUCH 10               NaN
# 122          SOUNDTOUCH 20 SERIES III               NaN
# 123    WAM 1500/WAM 1501 / SPEAKER R1               NaN
# 124                  CHROMECAST AUDIO               NaN
# 125                     PLAY:5 (GEN2)               NaN
# 126    SOUNDTOUCH 10 X 2 STARTER PACK               NaN
# 127                              HOME               NaN
# 128                           HOMEPOD               NaN
# 129                         HOME MINI               NaN
# 130                   ECHO (2ND GEN.)               NaN
# 131                               ONE               NaN
# 132                         ECHO PLUS               NaN
# 133               ECHO DOT (2ND GEN.)               NaN
# 134                         ECHO SPOT               NaN
# 135                               WK7               NaN
# 136              ECHO PLUS (2ND GEN.)               NaN
# 137         ECHO DOT (3RD GENERATION)               NaN
# 138                         ECHO SHOW               NaN
# 139              ECHO SHOW (2ND GEN.)               NaN
# 140                          HOME HUB               NaN
# 141      CONNECT:AMP (ZONEPLAYER 120)               NaN
# 142           CONNECT (ZONEPLAYER 90)               NaN
# 143                            PLAY:3               NaN
# 144                            PLAY:1               NaN
